# %%
# Import modules

from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.animation import FuncAnimation
import pandas as pd
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Enable interactive plot
# %matplotlib notebook
# %matplotlib notebook

import subprocess
import sys

# Import PySwarms
import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx
from pyswarms.utils.plotters import (plot_cost_history, plot_contour, plot_surface)
from pyswarms.utils.plotters.formatters import Mesher

global particle_number
particle_number=0

from math import floor

import random

# %% [markdown]
# ## Load the goal data

# %%
push_data = pd.read_csv('PushData.csv',sep=";")[['MaxForce', 'PerturbationDuration','Final_CoM_x']]
push_data.head()
# Out:
#     MaxForce  PerturbationDuration  Final_CoM_x
# 0  78.075649                 0.875    -0.456892
# 1  72.194312                 0.825    -0.354812
# 2  60.788209                 1.030    -0.335891
# 3  71.539533                 0.860    -0.293160
# 4  44.182392                 0.850    -0.088240

# %% [markdown]
# ## Fonction evaluant la stabilité du CoM en fonction des poids kd,kp

# %%
def weight_impact_function(kd1,kd2,kd3,kd4,kd5,kd6,kd7,kd8,kd9,kd10,kd11,kd12,kd13,kd14,kd15,kd16,kd17,kd18,kp1,kp2,kp3,kp4,kp5,kp6,kp7,kp8,kp9,kp10,kp11,kp12,kp13,kp14,kp15,kp16,kp17,kp18,force,time):
   
    kds = kd1,kd2,kd3,kd4,kd5,kd6,kd7,kd8,kd9,kd10,kd11,kd12,kd13,kd14,kd15,kd16,kd17,kd18
    kps = kp1,kp2,kp3,kp4,kp5,kp6,kp7,kp8,kp9,kp10,kp11,kp12,kp13,kp14,kp15,kp16,kp17,kp18
    
    f = open("input.txt", "w")
    f.write(('\n'.join(str(kds[i]) + " "+ str(kps[i]) for i in range(18))).replace("[","").replace("]",""))
    f.write("\n" + str(force) + " " + str(time) +"\n")
    f.close()

    subprocess.check_call(['../../bin/App_BulletExampleBrowser_vs2010_x64_debug.exe'])

    donnee_1 = pd.read_csv('output.txt', sep=" ")
    
    result = donnee_1["Z"].iat[-1]
    return result


def all_particles(kd1,kd2,kd3,kd4,kd5,kd6,kd7,kd8,kd9,kd10,kd11,kd12,kd13,kd14,kd15,kd16,kd17,kd18,kp2,kp3,kp4,kp5,kp6,kp7,kp8,kp9,kp10,kp11,kp12,kp13,kp14,kp15,kp16,kp17,kp18,force,time):
    result =[0,0]
    
    
    for j in range(5):
        current_test = push_data.iloc[random.randint(0,len(push_data)-1)].to_numpy()
        print(current_test)
        for i in range(2):
            temp_kd1 = kd1[i][0]
            temp_kp1 = kd1[i][1]
            temp = abs(abs(current_test[2])+weight_impact_function(temp_kd1,kd2,kd3,kd4,kd5,kd6,kd7,kd8,kd9,kd10,kd11,kd12,kd13,kd14,kd15,kd16,kd17,kd18,temp_kp1,kp2,kp3,kp4,kp5,kp6,kp7,kp8,kp9,kp10,kp11,kp12,kp13,kp14,kp15,kp16,kp17,kp18,current_test[0],current_test[1]))
            result[i] = result[i] + temp
            print("Diff "+ str(i) +" : " + str(abs(current_test[2])) + " - " + str(temp-abs(current_test[2])) + " -> " + str(temp) +"\n")
    
    print(result)
    return result

# %% [markdown]
# ## Lancer la fonction une fois

# %%
kds = -1200, 0, -900, -900, -20, -20, -900, -900, -20, -20, -20, -20, -1200, -1200, -20, -10, -20, -10
kps = -10,0,-10, -10, -1, -1, -10, -10, -1.5, -1.5, -1.5, -1.5, -10, -10, -1, 0, -1, 0

result = weight_impact_function(-1200, 0, -900, -900, -20, -20, -900, -900, -20, -20, -20, -20, -1200, -1200, -20, -10, -20, -10,-10,0,-10, -10, -1, -1, -10, -10, -1.5, -1.5, -1.5, -1.5, -10, -10, -1, 0, -1, 0, 36,0.55)
print(result)
##donnee_1.head()
# Out:
# -0.445015

# %% [markdown]
# ## Optimiser

# %%
kwargs = { "kd2":0, "kd3":-900, "kd4":-900, "kd5":-20, "kd6":-20, "kd7":-900, "kd8":-900, "kd9":-20, "kd10":-20, "kd11":-20, "kd12":-20, "kd13":-1200, "kd14":-1200, "kd15":-20, "kd16":-10, "kd17":-20, "kd18":-10,"kp2":0,"kp3":-10, "kp4":-10, "kp5":-1, "kp6":-1, "kp7":-10, "kp8":-10, "kp9":-1.5, "kp10":-1.5, "kp11":-1.5, "kp12":-1.5, "kp13":-20, "kp14":-20, "kp15":-1, "kp16":0, "kp17":-1, "kp18":0,"force":36,"time":0.55}
max_bound = np.array([-1100,-15])
min_bound = np.array([-1300,-25])
bounds = (min_bound, max_bound)
options = {'c1':1, 'c2':1, 'w':0.9}
optimizer = ps.single.GlobalBestPSO(n_particles=2, dimensions=2, options=options, bounds=bounds)
cost, pos = optimizer.optimize(all_particles, **kwargs,iters=2)
# Out:
# 2023-01-18 14:11:31,525 - pyswarms.single.global_best - INFO - Optimize for 2 iters with {'c1': 1, 'c2': 1, 'w': 0.9}
# pyswarms.single.global_best:   0%|                                                                                 |0/2
# [42.02897586  0.515       0.11281189]
# Diff 0 : 0.112811889168306 - 0.073313221663388 -> 0.186125110831694
#
# Diff 1 : 0.112811889168306 - 0.10057822166338798 -> 0.21339011083169399
#
# [6.20469943e+01 8.30000000e-01 1.72299156e-02]
# Diff 0 : 0.0172299155591482 - 0.23218416888170357 -> 0.24941408444085178
#
# Diff 1 : 0.0172299155591482 - 0.23187116888170356 -> 0.24910108444085177
#
# [61.4301488   0.645      -0.09962059]
# Diff 0 : 0.0996205860947807 - -0.04696017218956139 -> 0.052660413905219305
#
# Diff 1 : 0.0996205860947807 - 0.026349827810438625 -> 0.12597041390521932
#
# [8.43205606e+01 7.75000000e-01 4.83075859e-02]
# Diff 0 : 0.0483075859494413 - 0.37344782810111743 -> 0.4217554140505587
#
# Diff 1 : 0.0483075859494413 - 0.3631888281011174 -> 0.4114964140505587
#
# [5.41995706e+01 5.30000000e-01 7.53987912e-03]
# Diff 0 : 0.0075398791214289 - 0.3156532417571422 -> 0.3231931208785711
# pyswarms.single.global_best:  50%|████████████████████████████████▌                                |1/2, best_cost=1.23
# Diff 1 : 0.0075398791214289 - 0.29125124175714223 -> 0.2987911208785711
#
# [1.2331481441068948, 1.298749144106895]
# [67.01385891  0.755       0.37792726]
# Diff 0 : 0.37792725923682 - -0.282108 -> 0.09581925923682
# pyswarms.single.global_best:  50%|████████████████████████████████▌                                |1/2, best_cost=1.23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 7
#       5 options = {'c1':1, 'c2':1, 'w':0.9}
#       6 optimizer = ps.single.GlobalBestPSO(n_particles=2, dimensions=2, options=options, bounds=bounds)
# ----> 7 cost, pos = optimizer.optimize(all_particles, **kwargs,iters=2)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\pyswarms\single\global_best.py:209, in GlobalBestPSO.optimize(self, objective_func, iters, n_processes, verbose, **kwargs)
#     205 ftol_history = deque(maxlen=self.ftol_iter)
#     206 for i in self.rep.pbar(iters, self.name) if verbose else range(iters):
#     207     # Compute cost for current position and personal best
#     208     # fmt: off
# --> 209     self.swarm.current_cost = compute_objective_function(self.swarm, objective_func, pool=pool, **kwargs)
#     210     self.swarm.pbest_pos, self.swarm.pbest_cost = compute_pbest(self.swarm)
#     211     # Set best_cost_yet_found for ftol
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\pyswarms\backend\operators.py:239, in compute_objective_function(swarm, objective_func, pool, **kwargs)
#     214 """Evaluate particles using the objective function
#     215
#     216 This method evaluates each particle in the swarm according to the objective
#    (...)
#     236     Cost-matrix for the given swarm
#     237 """
#     238 if pool is None:
# --> 239     return objective_func(swarm.position, **kwargs)
#     240 else:
#     241     results = pool.map(
#     242         partial(objective_func, **kwargs),
#     243         np.array_split(swarm.position, pool._processes),
#     244     )
#
# Cell In[7], line 29, in all_particles(kd1, kd2, kd3, kd4, kd5, kd6, kd7, kd8, kd9, kd10, kd11, kd12, kd13, kd14, kd15, kd16, kd17, kd18, kp2, kp3, kp4, kp5, kp6, kp7, kp8, kp9, kp10, kp11, kp12, kp13, kp14, kp15, kp16, kp17, kp18, force, time)
#      27 temp_kd1 = kd1[i][0]
#      28 temp_kp1 = kd1[i][1]
# ---> 29 temp = abs(abs(current_test[2])+weight_impact_function(temp_kd1,kd2,kd3,kd4,kd5,kd6,kd7,kd8,kd9,kd10,kd11,kd12,kd13,kd14,kd15,kd16,kd17,kd18,temp_kp1,kp2,kp3,kp4,kp5,kp6,kp7,kp8,kp9,kp10,kp11,kp12,kp13,kp14,kp15,kp16,kp17,kp18,current_test[0],current_test[1]))
#      30 result[i] = result[i] + temp
#      31 print("Diff "+ str(i) +" : " + str(abs(current_test[2])) + " - " + str(temp-abs(current_test[2])) + " -> " + str(temp) +"\n")
#
# Cell In[7], line 11, in weight_impact_function(kd1, kd2, kd3, kd4, kd5, kd6, kd7, kd8, kd9, kd10, kd11, kd12, kd13, kd14, kd15, kd16, kd17, kd18, kp1, kp2, kp3, kp4, kp5, kp6, kp7, kp8, kp9, kp10, kp11, kp12, kp13, kp14, kp15, kp16, kp17, kp18, force, time)
#       8 f.write("\n" + str(force) + " " + str(time) +"\n")
#       9 f.close()
# ---> 11 subprocess.check_call(['../../bin/App_BulletExampleBrowser_vs2010_x64_debug.exe'])
#      13 donnee_1 = pd.read_csv('output.txt', sep=" ")
#      15 result = donnee_1["Z"].iat[-1]
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\subprocess.py:359, in check_call(*popenargs, **kwargs)
#     349 def check_call(*popenargs, **kwargs):
#     350     """Run command with arguments.  Wait for command to complete.  If
#     351     the exit code was zero then return, otherwise raise
#     352     CalledProcessError.  The CalledProcessError object will have the
#    (...)
#     357     check_call(["ls", "-l"])
#     358     """
# --> 359     retcode = call(*popenargs, **kwargs)
#     360     if retcode:
#     361         cmd = kwargs.get("args")
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\subprocess.py:342, in call(timeout, *popenargs, **kwargs)
#     340 with Popen(*popenargs, **kwargs) as p:
#     341     try:
# --> 342         return p.wait(timeout=timeout)
#     343     except:  # Including KeyboardInterrupt, wait handled that.
#     344         p.kill()
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\subprocess.py:1083, in Popen.wait(self, timeout)
#    1081     endtime = _time() + timeout
#    1082 try:
# -> 1083     return self._wait(timeout=timeout)
#    1084 except KeyboardInterrupt:
#    1085     # https://bugs.python.org/issue25942
#    1086     # The first keyboard interrupt waits briefly for the child to
#    1087     # exit under the common assumption that it also received the ^C
#    1088     # generated SIGINT and will exit rapidly.
#    1089     if timeout is not None:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\subprocess.py:1361, in Popen._wait(self, timeout)
#    1358     timeout_millis = int(timeout * 1000)
#    1359 if self.returncode is None:
#    1360     # API note: Returns immediately if timeout_millis == 0.
# -> 1361     result = _winapi.WaitForSingleObject(self._handle,
#    1362                                          timeout_millis)
#    1363     if result == _winapi.WAIT_TIMEOUT:
#    1364         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualiser l'optimisation

# %%
plot_cost_history(cost_history=optimizer.cost_history)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Make animation
myList= optimizer.pos_history
liste = [x for x in optimizer.pos_history]

#print(liste)

#aimation = plot_contour(pos_history=liste,title='Yay')

# %%
itera=50
partic=20

interp=30

x = []
y = []
for i in range(itera):
        for j in range(partic):
            x.append(liste[i][j][0])
            y.append(liste[i][j][1])   
            
            

fig, ax = plt.subplots()
points, = ax.plot(x, y, marker='o', linestyle='None')

 
            
progress = 1

def animate(frame_num):
    plt.cla()
    ax.set_xlabel('Valeur de Kp')
    ax.set_ylabel('Valeur de Kd')
    ax.set_title('Swarm Optimisation')
    
    
    ax.set_xlim(-1300,-1100)
    ax.set_ylim(-25,-15)
    
    x=[]
    y=[]
    for j in range(partic):
        x.append(liste[floor(frame_num/interp)][j][0])
        y.append(liste[floor(frame_num/interp)][j][1])
        
        if(floor(frame_num/interp) < itera):
            x[j] = [(1-(frame_num%interp * 1/interp)) * x[j] + frame_num%interp * 1/interp * liste[floor(frame_num/interp)+1][j][0]]
            y[j] = [(1-(frame_num%interp * 1/interp)) * y[j] + frame_num%interp * 1/interp * liste[floor(frame_num/interp)+1][j][1]]

    points, = ax.plot(x, y, marker='o', linestyle='None')
    
    points.set_data((x,y))
    
    return points

anim = FuncAnimation(fig, animate, frames=itera*interp, interval=5, repeat=False)
plt.show()

# %%
# Enables us to view it in a Jupyter notebook
anim.save('plot0.gif', writer='imagemagick', fps=30)
Image(url='plot0.gif')
# Out:
# 2023-01-11 10:02:36,438 - matplotlib.animation - WARNING - MovieWriter imagemagick unavailable; using Pillow instead.
# 2023-01-11 10:02:36,439 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.PillowWriter'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Enables us to view it in a Jupyter notebook
# ----> 2 anim.save('plot0.gif', writer='imagemagick', fps=30)
#       3 Image(url='plot0.gif')
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py:1081, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1078 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1079     for anim, d in zip(all_anim, data):
#    1080         # TODO: See if turning off blit is really necessary
# -> 1081         anim._draw_next_frame(d, blit=False)
#    1082         if progress_callback is not None:
#    1083             progress_callback(frame_number, total_frames)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py:1116, in Animation._draw_next_frame(self, framedata, blit)
#    1112 def _draw_next_frame(self, framedata, blit):
#    1113     # Breaks down the drawing of the next frame into steps of pre- and
#    1114     # post- draw, as well as the drawing of the frame itself.
#    1115     self._pre_draw(framedata, blit)
# -> 1116     self._draw_frame(framedata)
#    1117     self._post_draw(framedata, blit)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py:1743, in FuncAnimation._draw_frame(self, framedata)
#    1739 self._save_seq = self._save_seq[-self.save_count:]
#    1741 # Call the func with framedata and args. If blitting is desired,
#    1742 # func needs to return a sequence of any artists that were modified.
# -> 1743 self._drawn_artists = self._func(framedata, *self._args)
#    1745 if self._blit:
#    1747     err = RuntimeError('The animation function must return a sequence '
#    1748                        'of Artist objects.')
#
# Cell In[29], line 39, in animate(frame_num)
#      36     y.append(liste[floor(frame_num/interp)][j][1])
#      38     if(floor(frame_num/interp) < itera):
# ---> 39         x[j] = [(1-(frame_num%interp * 1/interp)) * x[j] + frame_num%interp * 1/interp * liste[floor(frame_num/interp)+1][j][0]]
#      40         y[j] = [(1-(frame_num%interp * 1/interp)) * y[j] + frame_num%interp * 1/interp * liste[floor(frame_num/interp)+1][j][1]]
#      42 points, = ax.plot(x, y, marker='o', linestyle='None')
#
# IndexError: list index out of range

# %% [markdown]
# ## Visualiser données

# %%
c1x=donnee_1["c1x"].to_numpy()
c1z=donnee_1["c1z"].to_numpy()
c2x=donnee_1["c2x"].to_numpy()
c2z=donnee_1["c2z"].to_numpy()
c3x=donnee_1["c3x"].to_numpy()
c3z=donnee_1["c3z"].to_numpy()
c4x=donnee_1["c4x"].to_numpy()
c4z=donnee_1["c4z"].to_numpy()
c5x=donnee_1["c5x"].to_numpy()
c5z=donnee_1["c5z"].to_numpy()
c6x=donnee_1["c6x"].to_numpy()
c6z=donnee_1["c6z"].to_numpy()
c7x=donnee_1["c7x"].to_numpy()
c7z=donnee_1["c7z"].to_numpy()
c8x=donnee_1["c8x"].to_numpy()
c8z=donnee_1["c8z"].to_numpy()
X=donnee_1["X"].to_numpy()
Z=donnee_1["Z"].to_numpy()
vX=donnee_1["vX"].to_numpy()
vZ=donnee_1["vZ"].to_numpy()

x = [0,0,0,0,0,0,0,0,0]
y = [0,0,0,0,0,0,0,0,0]
fig, ax = plt.subplots()
points, = ax.plot(x, y, marker='o', linestyle='None')




progress = 1

def animate(frame_num):
    plt.cla()
    ax.set_xlabel('Coordonnée X')
    ax.set_ylabel('Coordonnée Z')
    ax.set_title('Position du COM')
    x = [0,0,0,0,0,0,0,0,0]
    y = [0,0,0,0,0,0,0,0,0]
    points, = ax.plot(x, y, marker='o', linestyle='None')

    ax.set_xlim(-1,1)
    ax.set_ylim(-2,2)
    x=[c1x[frame_num],c2x[frame_num],c3x[frame_num],c4x[frame_num],c5x[frame_num],c6x[frame_num],c7x[frame_num],c8x[frame_num],X[frame_num]]
    y=[c1z[frame_num],c2z[frame_num],c3z[frame_num],c4z[frame_num],c5z[frame_num],c6z[frame_num],c7z[frame_num],c8z[frame_num],Z[frame_num]]
    points.set_data((x,y))
    
    plt.plot([c1x[frame_num],c2x[frame_num],c4x[frame_num],c3x[frame_num],c1x[frame_num]],
             [c1z[frame_num],c2z[frame_num],c4z[frame_num],c3z[frame_num],c1z[frame_num]], 'o', linestyle="-", color='red')
    
    plt.plot([c5x[frame_num],c6x[frame_num],c8x[frame_num],c7x[frame_num],c5x[frame_num]],
             [c5z[frame_num],c6z[frame_num],c8z[frame_num],c7z[frame_num],c5z[frame_num]], 'o', linestyle="-", color='orange')
    
    plt.plot([X[frame_num],X[frame_num]+vX[frame_num]],
             [Z[frame_num],Z[frame_num]+vZ[frame_num]], linestyle="-.", color='blue')
    
    
    return points

anim = FuncAnimation(fig, animate, frames=len(donnee_1), interval=5, repeat=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 c1x=donnee_1["c1x"].to_numpy()
#       2 c1z=donnee_1["c1z"].to_numpy()
#       3 c2x=donnee_1["c2x"].to_numpy()
#
# NameError: name 'donnee_1' is not defined

# %%
# Out:
# 83.03144066280001

# %%
import matplotlib.animation as animation

f = "animation.gif" 
writergif = animation.PillowWriter(fps=30) 
anim.save(f, writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 5
#       3 f = "animation.gif"
#       4 writergif = animation.PillowWriter(fps=30)
# ----> 5 anim.save(f, writer=writergif)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py:1085, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1083         progress_callback(frame_number, total_frames)
#    1084         frame_number += 1
# -> 1085 writer.grab_frame(**savefig_kwargs)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py:491, in PillowWriter.grab_frame(self, **savefig_kwargs)
#     489 def grab_frame(self, **savefig_kwargs):
#     490     buf = BytesIO()
# --> 491     self.fig.savefig(
#     492         buf, **{**savefig_kwargs, "format": "rgba", "dpi": self.dpi})
#     493     self._frames.append(Image.frombuffer(
#     494         "RGBA", self.frame_size, buf.getbuffer(), "raw", "RGBA", 0, 1))
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
#    3270     for ax in self.axes:
#    3271         stack.enter_context(
#    3272             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3274 self.canvas.print_figure(fname, **kwargs)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\_api\deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backends\backend_agg.py:451, in FigureCanvasAgg.print_raw(self, filename_or_obj, *args)
#     449 @_api.delete_parameter("3.5", "args")
#     450 def print_raw(self, filename_or_obj, *args):
# --> 451     FigureCanvasAgg.draw(self)
#     452     renderer = self.get_renderer()
#     453     with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backends\backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\figure.py:3071, in Figure.draw(self, renderer)
#    3068         # ValueError can occur when resizing a window.
#    3070 self.patch.draw(renderer)
# -> 3071 mimage._draw_list_compositing_images(
#    3072     renderer, self, artists, self.suppressComposite)
#    3074 for sfig in self.subfigs:
#    3075     sfig.draw(renderer)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_base.py:3107, in _AxesBase.draw(self, renderer)
#    3104         a.draw(renderer)
#    3105     renderer.stop_rasterizing()
# -> 3107 mimage._draw_list_compositing_images(
#    3108     renderer, self, artists, self.figure.suppressComposite)
#    3110 renderer.close_group('axes')
#    3111 self.stale = False
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axis.py:1304, in Axis.draw(self, renderer, *args, **kwargs)
#    1301     return
#    1302 renderer.open_group(__name__, gid=self.get_gid())
# -> 1304 ticks_to_draw = self._update_ticks()
#    1305 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1307 for tick in ticks_to_draw:
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axis.py:1190, in Axis._update_ticks(self)
#    1185 def _update_ticks(self):
#    1186     """
#    1187     Update ticks (position and labels) using the current data interval of
#    1188     the axes.  Return the list of ticks that will be drawn.
#    1189     """
# -> 1190     major_locs = self.get_majorticklocs()
#    1191     major_labels = self.major.formatter.format_ticks(major_locs)
#    1192     major_ticks = self.get_major_ticks(len(major_locs))
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axis.py:1416, in Axis.get_majorticklocs(self)
#    1414 def get_majorticklocs(self):
#    1415     """Return this Axis' major tick locations in data coordinates."""
# -> 1416     return self.major.locator()
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\ticker.py:2143, in MaxNLocator.__call__(self)
#    2141 def __call__(self):
#    2142     vmin, vmax = self.axis.get_view_interval()
# -> 2143     return self.tick_values(vmin, vmax)
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\ticker.py:2151, in MaxNLocator.tick_values(self, vmin, vmax)
#    2148     vmin = -vmax
#    2149 vmin, vmax = mtransforms.nonsingular(
#    2150     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2151 locs = self._raw_ticks(vmin, vmax)
#    2153 prune = self._prune
#    2154 if prune == 'lower':
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\ticker.py:2090, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2088 if self._nbins == 'auto':
#    2089     if self.axis is not None:
# -> 2090         nbins = np.clip(self.axis.get_tick_space(),
#    2091                         max(1, self._min_n_ticks - 1), 9)
#    2092     else:
#    2093         nbins = 9
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axis.py:2423, in XAxis.get_tick_space(self)
#    2422 def get_tick_space(self):
# -> 2423     ends = mtransforms.Bbox.unit().transformed(
#    2424         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2425     length = ends.width * 72
#    2426     # There is a heuristic here that the aspect ratio of tick text
#    2427     # is no more than 3:1
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py:481, in BboxBase.transformed(self, transform)
#     478 pts = self.get_points()
#     479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
# --> 481 return Bbox([ll, [lr[0], ul[1]]])
#
# File c:\users\ajensen\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py:772, in Bbox.__init__(self, points, **kwargs)
#     768 self._ignore = True
#     769 # it is helpful in some contexts to know if the bbox is a
#     770 # default or has been mutated; we store the orig points to
#     771 # support the mutated methods
# --> 772 self._points_orig = self._points.copy()
#
# KeyboardInterrupt:
