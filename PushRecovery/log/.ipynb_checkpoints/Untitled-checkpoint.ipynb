# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Enable interactive plot
# %matplotlib notebook
# %matplotlib notebook

# %%
donnee_1 = pd.read_csv('Donnée_10x1000_1.txt', sep=" ")
donnee_1.head()
# Out:
#         c1x       c1z       c2x       c2z       c3x       c3z       c4x  \
# 0       NaN -0.361262  0.350062 -0.363626 -0.349908 -0.057654 -0.157408
# 1  0.166458 -0.055945  0.358868 -0.061581  0.157559 -0.359815  0.349968
# 2  0.172205 -0.054663  0.364481 -0.063923  0.157580 -0.358311  0.349856
# 3  0.177672 -0.053420  0.369747 -0.066077  0.157674 -0.356760  0.349749
# 4  0.177385 -0.053339  0.369461 -0.065993  0.157390 -0.356678  0.349466
#
#         c4z       c5x       c5z       c6x       c6z       c7x       c7z  \
# 0 -0.057654 -0.349908 -0.361654 -0.157408 -0.361654 -0.000000 -0.005899
# 1 -0.365450 -0.353253 -0.059028 -0.160815 -0.056817 -0.349760 -0.363008
# 2 -0.367571 -0.357032 -0.060397 -0.164676 -0.055859 -0.349863 -0.364312
# 3 -0.369416 -0.359294 -0.062928 -0.166939 -0.058357 -0.352125 -0.366839
# 4 -0.369332 -0.365408 -0.055307 -0.173665 -0.050720 -0.358145 -0.359221
#
#         c8x       c8z         X         Z        vX        vZ
# 0 -0.000019 -0.008070       NaN       NaN       NaN       NaN
# 1 -0.157322 -0.360797 -0.000000 -0.005934 -0.000003 -0.008042
# 2 -0.157507 -0.359774 -0.000001 -0.005968 -0.000054 -0.008045
# 3 -0.159769 -0.362268  0.000054 -0.006050  0.003344 -0.010962
# 4 -0.166402 -0.354633 -0.000121 -0.005625 -0.010599  0.019888

# %%
     

c1x=donnee_1["c1x"].to_numpy()
c1z=donnee_1["c1z"].to_numpy()
c2x=donnee_1["c2x"].to_numpy()
c2z=donnee_1["c2z"].to_numpy()
c3x=donnee_1["c3x"].to_numpy()
c3z=donnee_1["c3z"].to_numpy()
c4x=donnee_1["c4x"].to_numpy()
c4z=donnee_1["c4z"].to_numpy()
c5x=donnee_1["c5x"].to_numpy()
c5z=donnee_1["c5z"].to_numpy()
c6x=donnee_1["c6x"].to_numpy()
c6z=donnee_1["c6z"].to_numpy()
c7x=donnee_1["c7x"].to_numpy()
c7z=donnee_1["c7z"].to_numpy()
c8x=donnee_1["c8x"].to_numpy()
c8z=donnee_1["c8z"].to_numpy()
X=donnee_1["X"].to_numpy()
Z=donnee_1["Z"].to_numpy()
vX=donnee_1["vX"].to_numpy()
vZ=donnee_1["vZ"].to_numpy()

x = [0,0,0,0,0,0,0,0,0]
y = [0,0,0,0,0,0,0,0,0]
fig, ax = plt.subplots()
points, = ax.plot(x, y, marker='o', linestyle='None')




progress = 1

def animate(frame_num):
    plt.cla()
    ax.set_xlabel('Coordonnée X')
    ax.set_ylabel('Coordonnée Z')
    ax.set_title('Position du COM')
    x = [0,0,0,0,0,0,0,0,0]
    y = [0,0,0,0,0,0,0,0,0]
    points, = ax.plot(x, y, marker='o', linestyle='None')

    ax.set_xlim(-1,1)
    ax.set_ylim(-1,1)
    x=[c1x[frame_num],c2x[frame_num],c3x[frame_num],c4x[frame_num],c5x[frame_num],c6x[frame_num],c7x[frame_num],c8x[frame_num],X[frame_num]]
    y=[c1z[frame_num],c2z[frame_num],c3z[frame_num],c4z[frame_num],c5z[frame_num],c6z[frame_num],c7z[frame_num],c8z[frame_num],Z[frame_num]]
    points.set_data((x,y))
    
    plt.plot([c1x[frame_num],c2x[frame_num],c3x[frame_num],c4x[frame_num],c1x[frame_num]],
             [c1z[frame_num],c2z[frame_num],c3z[frame_num],c4z[frame_num],c1z[frame_num]], 'o', linestyle="-", color='red')
    
    plt.plot([c5x[frame_num],c6x[frame_num],c7x[frame_num],c8x[frame_num],c5x[frame_num]],
             [c5z[frame_num],c6z[frame_num],c7z[frame_num],c8z[frame_num],c5z[frame_num]], 'o', linestyle="-", color='orange')
    
    plt.plot([X[frame_num],X[frame_num]+vX[frame_num]],
             [Z[frame_num],Z[frame_num]+vZ[frame_num]], linestyle="-.", color='blue')
    
    
    return points

anim = FuncAnimation(fig, animate, frames=len(donnee_1), interval=50, repeat=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.animation as animation

f = "animation.gif" 
writergif = animation.PillowWriter(fps=30) 
anim.save(f, writer=writergif)
