# %%
print('Hello')
# Out:
# Hello

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
donnee_1 = pd.read_csv('Donnée_10x1000_1.txt', sep=" ", index_col=0)
donnee_2 = pd.read_csv('Donnée_10x1000_2.txt', sep=" ", index_col=0)
donnee_3 = pd.read_csv('Donnée_10x1000_3.txt', sep=" ", index_col=0)
donnee_4 = pd.read_csv('Donnée_10x1000_4.txt', sep=" ", index_col=0)
donnee_5 = pd.read_csv('Donnée_10x1000_5.txt', sep=" ", index_col=0)
donnee_6 = pd.read_csv('Donnée_10x1000_6.txt', sep=" ", index_col=0)
donnee_7 = pd.read_csv('Donnée_10x1000_7.txt', sep=" ", index_col=0)
donnee_8 = pd.read_csv('Donnée_10x1000_8.txt', sep=" ", index_col=0)
donnee_9 = pd.read_csv('Donnée_10x1000_9.txt', sep=" ", index_col=0)
donnee_10 = pd.read_csv('Donnée_10x1000_10.txt', sep=" ", index_col=0)
donnee_2.head()
# Out:
#             X         Y         Z
# Time
# 0.100000 -0.0  2.036861 -0.005862
# 0.013718  0.0  2.034139 -0.005862
# 0.010567  0.0  2.034139 -0.005862
# 0.012583 -0.0  2.028694 -0.005862
# 0.012251 -0.0  2.020528 -0.005862

# %%
donnee_2.plot()
# Out:
# <AxesSubplot: xlabel='Time'>

# %%
plt.show()

# %%
donnee_1.plot.scatter(x="X", y="Z", alpha=0.5)
plt.show()

# %%
total_1 = donnee_1["X"].abs().sum() + donnee_1["Z"].abs().sum()
total_2 = donnee_2["X"].abs().sum() + donnee_2["Z"].abs().sum()
total_3 = donnee_3["X"].abs().sum() + donnee_3["Z"].abs().sum()
total_4 = donnee_4["X"].abs().sum() + donnee_4["Z"].abs().sum()
total_5 = donnee_5["X"].abs().sum() + donnee_5["Z"].abs().sum()
total_6 = donnee_6["X"].abs().sum() + donnee_6["Z"].abs().sum()
total_7 = donnee_7["X"].abs().sum() + donnee_7["Z"].abs().sum()
total_8 = donnee_8["X"].abs().sum() + donnee_8["Z"].abs().sum()
total_9 = donnee_9["X"].abs().sum() + donnee_9["Z"].abs().sum()
total_10 = donnee_10["X"].abs().sum() + donnee_10["Z"].abs().sum()

# %%
list=[total_1,total_2,total_3,total_4,total_5,total_6,total_7,total_8,total_9,total_10]

# %%
df = pd.DataFrame(list,index=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000],columns=['Sum of deviation from (0,0)'])
df.head()
df.plot()
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots()

# %%
ax.plot(donnee_1)
ax.set_xlabel('Coordonnée X')
ax.set_ylabel('Coordonnée Z')
ax.set_title('Position du COM')
# Out:
# Text(0.5, 1.0, 'Position du COM')

# %%
fig.savefig('static_plot.png')

# %%
plt.show()

# %%
# Enable interactive plot
# %matplotlib notebook
# %matplotlib notebook

# %%
from matplotlib.animation import FuncAnimation

# %%
# create empty lists for the x and y data
x = []
y = []

# create the figure and axes objects
fig, ax = plt.subplots()

# function that draws each frame of the animation
def animate(frame_num):
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data((x, y))
    return line
    
ani = FuncAnimation(fig, animate, frames=20, interval=500, repeat=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

fig, ax = plt.subplots()

line, = ax.plot([])

ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)

def animate(frame_num):
    y = 0
    line.set_data((x, y))
    return line

anim = FuncAnimation(fig, animate, frames=100, interval=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
